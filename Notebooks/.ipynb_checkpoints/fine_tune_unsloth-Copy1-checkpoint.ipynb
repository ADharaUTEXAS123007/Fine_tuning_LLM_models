# %%
import sys
import os
#os.environ["HF_HOME"] = "/scratch/09143/arnabd/cache"
# Add a custom directory to the module search path
sys.path.append('/work/09143/arnabd/ls6/Fine_tune_LLMS/Fine_tuning_LLM_models/.')
from UnslothFineTuner import UnslothFineTuner
# Set the custom cache directory before importing transformers/unsloth

# %%
fine_tuner = UnslothFineTuner(
    base_model="unsloth/llama-3-8b-bnb-4bit",
    dataset_name="danivpv/ml-arxiv-instruct",
)

#fine_tuner.train(num_train_epochs=1, per_device_train_batch_size=2)
# Out:
# ==((====))==  Unsloth 2025.5.5: Fast Llama patching. Transformers: 4.51.3.
#    \\   /|    NVIDIA A100-PCIE-40GB. Num GPUs = 1. Max memory: 39.394 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 8.0. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Map:   0%|          | 0/481 [00:00<?, ? examples/s]

# %%
#Test the model
fine_tuner.infer("Discuss importance of training data in large language models?")
# Out:
# 'Discuss the importance of training data in large language models?\nThe importance of training data in large language models is that it allows the model to learn the language it is trained on. The more data a language model is trained on, the better it will be at generating natural language. This is because the model will have seen a wider range of sentences and phrases, and will be able to better understand the context of the sentences it generates. Training data is also important because it allows the model to learn the language it is trained on. The more data a language model is trained on, the better it will be at generating natural language. This is because the model will have seen a wider range of sentences and phrases, and will be able to better understand the context of the sentences it generates.\nTraining data is important in large language models because it allows the model to learn the language it is trained on. The more data a language model is trained on, the better it 
# ...

# %%
fine_tuner.train(num_train_epochs=1, per_device_train_batch_size=2)
# Out:
# Detected kernel version 4.18.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 481 | Num Epochs = 1 | Total steps = 241
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 1
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 1 x 1) = 2
#  "-____-"     Trainable parameters = 41,943,040/8,000,000,000 (0.52% trained)
#     <div>
#
#       <progress value='241' max='241' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [241/241 01:43, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.072500</td>
#     </tr>
#     <tr>
# ...

# %%
#Test the model
fine_tuner.infer("Discuss importance of training data in large language models?")
# Out:
# "Training data is paramount in the development of large language models as it serves as the foundation upon which the models learn and acquire linguistic capabilities. The diversity and quality of the data directly influence the model's ability to generate coherent and contextually relevant responses. A rich dataset allows the model to learn various patterns and nuances of human language, which ultimately leads to more sophisticated interactions. Therefore, investing in high-quality training data is essential for creating robust and effective large language models."
